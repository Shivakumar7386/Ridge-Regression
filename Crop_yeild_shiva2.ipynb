# %%
import pandas as pd

# %%
yield_data = pd.read_csv('/content/yield.csv')

# %%
yield_data.head(10)
# Out:
#   Domain Code Domain  Area Code         Area  Element Code Element  Item Code  \
# 0          QC  Crops          2  Afghanistan          5419   Yield         56
# 1          QC  Crops          2  Afghanistan          5419   Yield         56
# 2          QC  Crops          2  Afghanistan          5419   Yield         56
# 3          QC  Crops          2  Afghanistan          5419   Yield         56
# 4          QC  Crops          2  Afghanistan          5419   Yield         56
# 5          QC  Crops          2  Afghanistan          5419   Yield         56
# 6          QC  Crops          2  Afghanistan          5419   Yield         56
# 7          QC  Crops          2  Afghanistan          5419   Yield         56
# 8          QC  Crops          2  Afghanistan          5419   Yield         56
# 9          QC  Crops          2  Afghanistan          5419   Yield         56
#
#     Item  Year Code  Year   Unit  Value
# 0  Maize       1961  1961  hg/ha  14000
# ...

# %%
yield_data.shape
# Out:
# (56717, 12)

# %%
yield_data.describe()
# Out:
#           Area Code  Element Code     Item Code     Year Code          Year  \
# count  56717.000000       56717.0  56717.000000  56717.000000  56717.000000
# mean     125.650422        5419.0    111.611651   1989.669570   1989.669570
# std       75.120195           0.0    101.278435     16.133198     16.133198
# min        1.000000        5419.0     15.000000   1961.000000   1961.000000
# 25%       58.000000        5419.0     56.000000   1976.000000   1976.000000
# 50%      122.000000        5419.0    116.000000   1991.000000   1991.000000
# 75%      184.000000        5419.0    125.000000   2004.000000   2004.000000
# max      351.000000        5419.0    489.000000   2016.000000   2016.000000
#
#                 Value
# count    56717.000000
# mean     62094.660084
# std      67835.932856
# min          0.000000
# 25%      15680.000000
# 50%      36744.000000
# 75%      86213.000000
# max    1000000.000000

# %%
yield_data.isna().sum()
# Out:
# Domain Code     0
# Domain          0
# Area Code       0
# Area            0
# Element Code    0
# Element         0
# Item Code       0
# Item            0
# Year Code       0
# Year            0
# Unit            0
# Value           0
# dtype: int64

# %%
yield_data.dtypes
# Out:
# Domain Code     object
# Domain          object
# Area Code        int64
# Area            object
# Element Code     int64
# Element         object
# Item Code        int64
# Item            object
# Year Code        int64
# Year             int64
# Unit            object
# Value            int64
# dtype: object

# %%
rain_data = pd.read_csv('/content/rainfall.csv')

# %%
rain_data.head(10)
# Out:
#           Area  Year average_rain_fall_mm_per_year
# 0  Afghanistan  1985                           327
# 1  Afghanistan  1986                           327
# 2  Afghanistan  1987                           327
# 3  Afghanistan  1989                           327
# 4  Afghanistan  1990                           327
# 5  Afghanistan  1991                           327
# 6  Afghanistan  1992                           327
# 7  Afghanistan  1993                           327
# 8  Afghanistan  1994                           327
# 9  Afghanistan  1995                           327

# %%
rain_data.describe()
# Out:
#               Year
# count  6727.000000
# mean   2001.354839
# std       9.530114
# min    1985.000000
# 25%    1993.000000
# 50%    2001.000000
# 75%    2010.000000
# max    2017.000000

# %%
rain_data.isna().sum()
# Out:
#  Area                              0
# Year                               0
# average_rain_fall_mm_per_year    774
# dtype: int64

# %%
rain_data['average_rain_fall_mm_per_year'] = rain_data['average_rain_fall_mm_per_year'].fillna(rain_data['average_rain_fall_mm_per_year'].mode()[0])

# %%
rain_data.isna().sum()
# Out:
#  Area                            0
# Year                             0
# average_rain_fall_mm_per_year    0
# dtype: int64

# %%
rain_data.dtypes
# Out:
#  Area                            object
# Year                              int64
# average_rain_fall_mm_per_year    object
# dtype: object

# %%
yield_data.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Element Code', 'Element',
#        'Item Code', 'Item', 'Year Code', 'Year', 'Unit', 'Value'],
#       dtype='object')

# %%
rain_data.columns
# Out:
# Index([' Area', 'Year', 'average_rain_fall_mm_per_year'], dtype='object')

# %%
rain_data = rain_data.rename(columns={' Area':'Area'})

# %%
yeild_rain = pd.merge(yield_data,rain_data,on=['Area','Year'],how='inner')

# %%
yeild_rain
# Out:
#       Domain Code Domain  Area Code         Area  Element Code Element  \
# 0              QC  Crops          2  Afghanistan          5419   Yield
# 1              QC  Crops          2  Afghanistan          5419   Yield
# 2              QC  Crops          2  Afghanistan          5419   Yield
# 3              QC  Crops          2  Afghanistan          5419   Yield
# 4              QC  Crops          2  Afghanistan          5419   Yield
# ...           ...    ...        ...          ...           ...     ...
# 26100          QC  Crops        181     Zimbabwe          5419   Yield
# 26101          QC  Crops        181     Zimbabwe          5419   Yield
# 26102          QC  Crops        181     Zimbabwe          5419   Yield
# 26103          QC  Crops        181     Zimbabwe          5419   Yield
# 26104          QC  Crops        181     Zimbabwe          5419   Yield
#
#        Item Code            Item  Year Code  Year   Unit   Value  \
# ...

# %%
pesticides_data = pd.read_csv('/content/pesticides.csv')

# %%
pesticides_data.head(10)
# Out:
#            Domain     Area Element                Item  Year  \
# 0  Pesticides Use  Albania     Use  Pesticides (total)  1990
# 1  Pesticides Use  Albania     Use  Pesticides (total)  1991
# 2  Pesticides Use  Albania     Use  Pesticides (total)  1992
# 3  Pesticides Use  Albania     Use  Pesticides (total)  1993
# 4  Pesticides Use  Albania     Use  Pesticides (total)  1994
# 5  Pesticides Use  Albania     Use  Pesticides (total)  1995
# 6  Pesticides Use  Albania     Use  Pesticides (total)  1996
# 7  Pesticides Use  Albania     Use  Pesticides (total)  1997
# 8  Pesticides Use  Albania     Use  Pesticides (total)  1998
# 9  Pesticides Use  Albania     Use  Pesticides (total)  1999
#
#                            Unit   Value
# 0  tonnes of active ingredients  121.00
# 1  tonnes of active ingredients  121.00
# 2  tonnes of active ingredients  121.00
# 3  tonnes of active ingredients  121.00
# 4  tonnes of active ingredients  201.00
# 5  tonnes of active ingredients  251.00
# ...

# %%
pesticides_data = pesticides_data.rename(columns={'Value':'Value_tones'})

# %%
pesticides_data = pesticides_data.drop(['Unit','Element'],axis=1)

# %%
pesticides_data
# Out:
#               Domain      Area                Item  Year  Value_tones
# 0     Pesticides Use   Albania  Pesticides (total)  1990       121.00
# 1     Pesticides Use   Albania  Pesticides (total)  1991       121.00
# 2     Pesticides Use   Albania  Pesticides (total)  1992       121.00
# 3     Pesticides Use   Albania  Pesticides (total)  1993       121.00
# 4     Pesticides Use   Albania  Pesticides (total)  1994       201.00
# ...              ...       ...                 ...   ...          ...
# 4344  Pesticides Use  Zimbabwe  Pesticides (total)  2012      3375.53
# 4345  Pesticides Use  Zimbabwe  Pesticides (total)  2013      2550.07
# 4346  Pesticides Use  Zimbabwe  Pesticides (total)  2014      2185.07
# 4347  Pesticides Use  Zimbabwe  Pesticides (total)  2015      2185.07
# 4348  Pesticides Use  Zimbabwe  Pesticides (total)  2016      2185.07
#
# [4349 rows x 5 columns]

# %%
yeild_rain.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Element Code', 'Element',
#        'Item Code', 'Item', 'Year Code', 'Year', 'Unit', 'Value',
#        'average_rain_fall_mm_per_year'],
#       dtype='object')

# %%
yeild_rain = yeild_rain.drop(['Domain Code','Item','Domain','Area Code','Element Code','Element','Item Code','Year Code','Unit'],axis=1)

# %%
yeild_rain
# Out:
#               Area  Year   Value average_rain_fall_mm_per_year
# 0      Afghanistan  1985   16652                           327
# 1      Afghanistan  1985  140909                           327
# 2      Afghanistan  1985   22482                           327
# 3      Afghanistan  1985   12277                           327
# 4      Afghanistan  1986   16875                           327
# ...            ...   ...     ...                           ...
# 26100     Zimbabwe  2016   22828                           657
# 26101     Zimbabwe  2016    2688                           657
# 26102     Zimbabwe  2016   12727                           657
# 26103     Zimbabwe  2016   22212                           657
# 26104     Zimbabwe  2016   18294                           657
#
# [26105 rows x 4 columns]

# %%
yeild_rain = yeild_rain.rename(columns={'Value':'Value_hg/ha'})

# %%
yeild_rain.columns
# Out:
# Index(['Area', 'Year', 'Value_hg/ha', 'average_rain_fall_mm_per_year'], dtype='object')

# %%
pesticides_data.columns
# Out:
# Index(['Domain', 'Area', 'Item', 'Year', 'Value_tones'], dtype='object')

# %%
yeild_rain_pest = pd.merge(yeild_rain,pesticides_data,on=['Area','Year'])

# %%
yeild_rain_pest
# Out:
#            Area  Year  Value_hg/ha average_rain_fall_mm_per_year  \
# 0       Albania  1990        36613                          1485
# 1       Albania  1990        66667                          1485
# 2       Albania  1990        23333                          1485
# 3       Albania  1990        12500                          1485
# 4       Albania  1990         7000                          1485
# ...         ...   ...          ...                           ...
# 19351  Zimbabwe  2016        22828                           657
# 19352  Zimbabwe  2016         2688                           657
# 19353  Zimbabwe  2016        12727                           657
# 19354  Zimbabwe  2016        22212                           657
# 19355  Zimbabwe  2016        18294                           657
#
#                Domain                Item  Value_tones
# 0      Pesticides Use  Pesticides (total)       121.00
# 1      Pesticides Use  Pesticides (total)       121.00
# ...

# %%
temp_data = pd.read_csv('/content/temp.csv')

# %%
temp_data.head(10)
# Out:
#    year        country  avg_temp
# 0  1849  Côte D'Ivoire     25.58
# 1  1850  Côte D'Ivoire     25.52
# 2  1851  Côte D'Ivoire     25.67
# 3  1852  Côte D'Ivoire       NaN
# 4  1853  Côte D'Ivoire       NaN
# 5  1854  Côte D'Ivoire       NaN
# 6  1855  Côte D'Ivoire       NaN
# 7  1856  Côte D'Ivoire     26.28
# 8  1857  Côte D'Ivoire     25.17
# 9  1858  Côte D'Ivoire     25.49

# %%
temp_data.describe()
# Out:
#                year      avg_temp
# count  71311.000000  68764.000000
# mean    1905.799007     16.183876
# std       67.102099      7.592960
# min     1743.000000    -14.350000
# 25%     1858.000000      9.750000
# 50%     1910.000000     16.140000
# 75%     1962.000000     23.762500
# max     2013.000000     30.730000

# %%
temp_data.isna().sum()
# Out:
# year           0
# country        0
# avg_temp    2547
# dtype: int64

# %%
temp_data['avg_temp'] = temp_data['avg_temp'].fillna(temp_data['avg_temp'].mode()[0])

# %%
temp_data.isna().sum()
# Out:
# year        0
# country     0
# avg_temp    0
# dtype: int64

# %%
temp_data.dtypes
# Out:
# year          int64
# country      object
# avg_temp    float64
# dtype: object

# %%
temp_data = temp_data.rename(columns={'country':'Area'})

# %%
temp_data = temp_data.rename(columns={'year':'Year'})

# %%
temp_data.columns
# Out:
# Index(['Year', 'Area', 'avg_temp'], dtype='object')

# %%
yeild_rain_pest.columns
# Out:
# Index(['Area', 'Year', 'Value_hg/ha', 'average_rain_fall_mm_per_year',
#        'Domain', 'Item', 'Value_tones'],
#       dtype='object')

# %%
yeild_rain_pest_temp  = pd.merge(yeild_rain_pest,temp_data,on=['Year','Area'],how='inner')

# %%
yeild_rain_pest_temp
# Out:
#            Area  Year  Value_hg/ha average_rain_fall_mm_per_year  \
# 0       Albania  1990        36613                          1485
# 1       Albania  1990        66667                          1485
# 2       Albania  1990        23333                          1485
# 3       Albania  1990        12500                          1485
# 4       Albania  1990         7000                          1485
# ...         ...   ...          ...                           ...
# 28243  Zimbabwe  2013        22581                           657
# 28244  Zimbabwe  2013         3066                           657
# 28245  Zimbabwe  2013        13142                           657
# 28246  Zimbabwe  2013        22222                           657
# 28247  Zimbabwe  2013        22888                           657
#
#                Domain                Item  Value_tones  avg_temp
# 0      Pesticides Use  Pesticides (total)       121.00     16.37
# ...

# %%
df = yeild_rain_pest_temp

# %%
df.describe()
# Out:
#                Year    Value_hg/ha    Value_tones      avg_temp
# count  28248.000000   28248.000000   28248.000000  28248.000000
# mean    2001.541950   77047.863282   37069.136973     20.543722
# std        7.052997   84950.194454   59954.787836      6.311828
# min     1990.000000      50.000000       0.040000      1.300000
# 25%     1995.000000   19918.750000    1695.710000     16.710000
# 50%     2001.000000   38295.000000   17517.760000     21.510000
# 75%     2008.000000  104598.250000   48687.880000     26.000000
# max     2013.000000  501412.000000  367778.000000     30.650000

# %%
df.isna().sum()
# Out:
# Area                             0
# Year                             0
# Value_hg/ha                      0
# average_rain_fall_mm_per_year    0
# Domain                           0
# Item                             0
# Value_tones                      0
# avg_temp                         0
# dtype: int64

# %%
df.dtypes
# Out:
# Area                              object
# Year                               int64
# Value_hg/ha                        int64
# average_rain_fall_mm_per_year     object
# Domain                            object
# Item                              object
# Value_tones                      float64
# avg_temp                         float64
# dtype: object
